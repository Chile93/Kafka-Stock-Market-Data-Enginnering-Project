# %%
import pandas as pd
from kafka import KafkaConsumer
from time import sleep
from json import loads
import json
from s3fs import S3FileSystem

# %%
#pip install --upgrade kafka-python

# %%
# consumer = KafkaConsumer(
#     'demo1',
#     bootstrap_servers=['3.87.227.99:9092'],
#     value_deserializer=lambda x: loads(x.decode('utf-8')),
#     auto_offset_reset='earliest'
# )

# %%
consumer = KafkaConsumer(
    'demo1',
    bootstrap_servers=['3.87.227.99:9092'],
    value_deserializer=lambda x: loads(x.decode('utf-8'))
)

# %%
for c in consumer:
    print(c.value)

# %%
s3 = S3FileSystem()

# %%
# for count, i in enumerate(consumer):
#     print(count)
#     print(i.value)

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-project93/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\aiohttp\connector.py:1173, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1169 try:
#    1170     # Cancelling this lookup should not cancel the underlying lookup
#    1171     #  or else the cancel event will get broadcast to all the waiters
#    1172     #  across all connections.
# -> 1173     hosts = await asyncio.shield(host_resolved)
#    1174 except asyncio.CancelledError:
#
# File ~\anaconda3\Lib\site-packages\aiohttp\connector.py:884, in TCPConnector._resolve_host(self, host, port, traces)
#     882         await trace.send_dns_resolvehost_start(host)
# --> 884 addrs = await self._resolver.resolve(host, port, family=self._family)
#     885 if traces:
#
# File ~\anaconda3\Lib\site-packages\aiohttp\resolver.py:33, in ThreadedResolver.resolve(self, hostname, port, family)
#      30 async def resolve(
#      31     self, hostname: str, port: int = 0, family: int = socket.AF_INET
#      32 ) -> List[Dict[str, Any]]:
# ---> 33     infos = await self._loop.getaddrinfo(
#      34         hostname,
#      35         port,
#      36         type=socket.SOCK_STREAM,
#      37         family=family,
#      38         flags=socket.AI_ADDRCONFIG,
#      39     )
#      41     hosts = []
#
# File ~\anaconda3\Lib\asyncio\base_events.py:868, in BaseEventLoop.getaddrinfo(self, host, port, family, type, proto, flags)
#     866     getaddr_func = socket.getaddrinfo
# --> 868 return await self.run_in_executor(
#     869     None, getaddr_func, host, port, family, type, proto, flags)
#
# File ~\anaconda3\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#
# File ~\anaconda3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\aiobotocore\httpsession.py:223, in AIOHTTPSession.send(self, request)
#     222 session = await self._get_session(proxy_url)
# --> 223 response = await session.request(
#     224     request.method,
#     225     url=url,
#     226     chunked=self._chunked(headers_),
#     227     headers=headers_,
#     228     data=data,
#     229     proxy=proxy_url,
#     230     proxy_headers=proxy_headers,
#     231 )
#     233 http_response = aiobotocore.awsrequest.AioAWSResponse(
#     234     str(response.url), response.status, response.headers, response
#     235 )
#
# File ~\anaconda3\Lib\site-packages\aiohttp\client.py:578, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     577         assert self._connector is not None
# --> 578         conn = await self._connector.connect(
#     579             req, traces=traces, timeout=real_timeout
#     580         )
#     581 except asyncio.TimeoutError as exc:
#
# File ~\anaconda3\Lib\site-packages\aiohttp\connector.py:544, in BaseConnector.connect(self, req, traces, timeout)
#     543 try:
# --> 544     proto = await self._create_connection(req, traces, timeout)
#     545     if self._closed:
#
# File ~\anaconda3\Lib\site-packages\aiohttp\connector.py:911, in TCPConnector._create_connection(self, req, traces, timeout)
#     910 else:
# --> 911     _, proto = await self._create_direct_connection(req, traces, timeout)
#     913 return proto
#
# File ~\anaconda3\Lib\site-packages\aiohttp\connector.py:1187, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1185     # in case of proxy it is not ClientProxyConnectionError
#    1186     # it is problem of resolving proxy ip itself
# -> 1187     raise ClientConnectorError(req.connection_key, exc) from exc
#    1189 last_exc: Optional[Exception] = None
#
# ClientConnectorError: Cannot connect to host kafka-stock-market-project93.s3.amazonaws.com:443 ssl:default [getaddrinfo failed]
#
# During handling of the above exception, another exception occurred:
#
# EndpointConnectionError                   Traceback (most recent call last)
# Cell In[24], line 2
#       1 for count, i in enumerate(consumer):
# ----> 2     with s3.open("s3://kafka-stock-market-project93/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~\anaconda3\Lib\site-packages\fsspec\spec.py:1932, in AbstractBufferedFile.close(self)
#    1930 else:
#    1931     if not self.forced:
# -> 1932         self.flush(force=True)
#    1934     if self.fs is not None:
#    1935         self.fs.invalidate_cache(self.path)
#
# File ~\anaconda3\Lib\site-packages\fsspec\spec.py:1803, in AbstractBufferedFile.flush(self, force)
#    1800         self.closed = True
#    1801         raise
# -> 1803 if self._upload_chunk(final=force) is not False:
#    1804     self.offset += self.buffer.seek(0, 2)
#    1805     self.buffer = io.BytesIO()
#
# File ~\anaconda3\Lib\site-packages\s3fs\core.py:2368, in S3File._upload_chunk(self, final)
#    2365     self.parts.append(part_header)
#    2367 if self.autocommit and final:
# -> 2368     self.commit()
#    2369 return not final
#
# File ~\anaconda3\Lib\site-packages\s3fs\core.py:2386, in S3File.commit(self)
#    2384     if self.acl:
#    2385         kw["ACL"] = self.acl
# -> 2386     write_result = self._call_s3("put_object", **kw)
#    2387 else:
#    2388     raise RuntimeError
#
# File ~\anaconda3\Lib\site-packages\s3fs\core.py:2231, in S3File._call_s3(self, method, *kwarglist, **kwargs)
#    2230 def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2231     return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\fsspec\asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\fsspec\asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~\anaconda3\Lib\site-packages\fsspec\asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~\anaconda3\Lib\site-packages\s3fs\core.py:362, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     360 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     361 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 362 return await _error_wrapper(
#     363     method, kwargs=additional_kwargs, retries=self.retries
#     364 )
#
# File ~\anaconda3\Lib\site-packages\s3fs\core.py:142, in _error_wrapper(func, args, kwargs, retries)
#     140         err = e
#     141 err = translate_boto_error(err)
# --> 142 raise err
#
# File ~\anaconda3\Lib\site-packages\s3fs\core.py:113, in _error_wrapper(func, args, kwargs, retries)
#     111 for i in range(retries):
#     112     try:
# --> 113         return await func(*args, **kwargs)
#     114     except S3_RETRYABLE_ERRORS as e:
#     115         err = e
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\client.py:388, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     384     maybe_compress_request(
#     385         self.meta.config, request_dict, operation_model
#     386     )
#     387     apply_request_checksum(request_dict)
# --> 388     http, parsed_response = await self._make_request(
#     389         operation_model, request_dict, request_context
#     390     )
#     392 await self.meta.events.emit(
#     393     'after-call.{service_id}.{operation_name}'.format(
#     394         service_id=service_id, operation_name=operation_name
#    (...)
#     399     context=request_context,
#     400 )
#     402 if http.status_code >= 300:
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\client.py:416, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     412 async def _make_request(
#     413     self, operation_model, request_dict, request_context
#     414 ):
#     415     try:
# --> 416         return await self._endpoint.make_request(
#     417             operation_model, request_dict
#     418         )
#     419     except Exception as e:
#     420         await self.meta.events.emit(
#     421             'after-call-error.{service_id}.{operation_name}'.format(
#     422                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     426             context=request_context,
#     427         )
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\endpoint.py:102, in AioEndpoint._send_request(self, request_dict, operation_model)
#      98 request = await self.create_request(request_dict, operation_model)
#      99 success_response, exception = await self._get_response(
#     100     request, operation_model, context
#     101 )
# --> 102 while await self._needs_retry(
#     103     attempts,
#     104     operation_model,
#     105     request_dict,
#     106     success_response,
#     107     exception,
#     108 ):
#     109     attempts += 1
#     110     self._update_retries_context(context, attempts, success_response)
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\endpoint.py:264, in AioEndpoint._needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     262 service_id = operation_model.service_model.service_id.hyphenize()
#     263 event_name = f"needs-retry.{service_id}.{operation_model.name}"
# --> 264 responses = await self._event_emitter.emit(
#     265     event_name,
#     266     response=response,
#     267     endpoint=self,
#     268     operation=operation_model,
#     269     attempts=attempts,
#     270     caught_exception=caught_exception,
#     271     request_dict=request_dict,
#     272 )
#     273 handler_response = first_non_none_response(responses)
#     274 if handler_response is None:
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\hooks.py:66, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      63 logger.debug('Event %s: calling handler %s', event_name, handler)
#      65 # Await the handler if its a coroutine.
# ---> 66 response = await resolve_awaitable(handler(**kwargs))
#      67 responses.append((handler, response))
#      68 if stop_on_response and response is not None:
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\_helpers.py:15, in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      17     return obj
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\retryhandler.py:107, in AioRetryHandler._call(self, attempts, response, caught_exception, **kwargs)
#     104     retries_context = kwargs['request_dict']['context'].get('retries')
#     105     checker_kwargs.update({'retries_context': retries_context})
# --> 107 if await resolve_awaitable(self._checker(**checker_kwargs)):
#     108     result = self._action(attempts=attempts)
#     109     logger.debug("Retry needed, action of: %s", result)
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\_helpers.py:15, in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      17     return obj
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\retryhandler.py:126, in AioMaxAttemptsDecorator._call(self, attempt_number, response, caught_exception, retries_context)
#     121 if retries_context:
#     122     retries_context['max'] = max(
#     123         retries_context.get('max', 0), self._max_attempts
#     124     )
# --> 126 should_retry = await self._should_retry(
#     127     attempt_number, response, caught_exception
#     128 )
#     129 if should_retry:
#     130     if attempt_number >= self._max_attempts:
#     131         # explicitly set MaxAttemptsReached
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\retryhandler.py:165, in AioMaxAttemptsDecorator._should_retry(self, attempt_number, response, caught_exception)
#     161         return True
#     162 else:
#     163     # If we've exceeded the max attempts we just let the exception
#     164     # propagate if one has occurred.
# --> 165     return await resolve_awaitable(
#     166         self._checker(attempt_number, response, caught_exception)
#     167     )
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\_helpers.py:15, in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      17     return obj
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\retryhandler.py:174, in AioMultiChecker._call(self, attempt_number, response, caught_exception)
#     171 async def _call(self, attempt_number, response, caught_exception):
#     172     for checker in self._checkers:
#     173         checker_response = await resolve_awaitable(
# --> 174             checker(attempt_number, response, caught_exception)
#     175         )
#     176         if checker_response:
#     177             return checker_response
#
# File ~\anaconda3\Lib\site-packages\botocore\retryhandler.py:247, in BaseChecker.__call__(self, attempt_number, response, caught_exception)
#     245     return self._check_response(attempt_number, response)
#     246 elif caught_exception is not None:
# --> 247     return self._check_caught_exception(
#     248         attempt_number, caught_exception
#     249     )
#     250 else:
#     251     raise ValueError("Both response and caught_exception are None.")
#
# File ~\anaconda3\Lib\site-packages\botocore\retryhandler.py:416, in ExceptionRaiser._check_caught_exception(self, attempt_number, caught_exception)
#     408 def _check_caught_exception(self, attempt_number, caught_exception):
#     409     # This is implementation specific, but this class is useful by
#     410     # coordinating with the MaxAttemptsDecorator.
#    (...)
#     414     # the MaxAttemptsDecorator is not interested in retrying the exception
#     415     # then this exception just propagates out past the retry code.
# --> 416     raise caught_exception
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\endpoint.py:183, in AioEndpoint._do_get_response(self, request, operation_model, context)
#     181     http_response = first_non_none_response(responses)
#     182     if http_response is None:
# --> 183         http_response = await self._send(request)
#     184 except HTTPClientError as e:
#     185     return (None, e)
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\endpoint.py:287, in AioEndpoint._send(self, request)
#     286 async def _send(self, request):
# --> 287     return await self.http_session.send(request)
#
# File ~\anaconda3\Lib\site-packages\aiobotocore\httpsession.py:268, in AIOHTTPSession.send(self, request)
#     262         raise ReadTimeoutError(endpoint_url=request.url, error=e)
#     263 except (
#     264     ClientConnectorError,
#     265     ClientConnectionError,
#     266     socket.gaierror,
#     267 ) as e:
# --> 268     raise EndpointConnectionError(endpoint_url=request.url, error=e)
#     269 except asyncio.TimeoutError as e:
#     270     raise ReadTimeoutError(endpoint_url=request.url, error=e)
#
# EndpointConnectionError: Could not connect to the endpoint URL: "https://kafka-stock-market-project93.s3.amazonaws.com/stock_market_0.json"
